# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import proc_img_algebra as proc_img

# %%
# %matplotlib inline

# %%
b = cv2.imread("img/image.jpg",cv2.IMREAD_UNCHANGED)
b = cv2.cvtColor(b,cv2.COLOR_BGR2RGB)

# %%
a = cv2.imread("/home/pablo/Yarn 002-L.jpg",cv2.IMREAD_UNCHANGED)
a = cv2.cvtColor(a,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(a)

# %%
plt.imshow(b)

# %%
img1 = np.zeros((b.shape[0],a.shape[1],3))
img2 = np.zeros((b.shape[0],a.shape[1],3))

# %%
img1[0:a.shape[0],0:a.shape[1]] = a/255
img2[0:b.shape[0],0:b.shape[1]] = b/255

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img1_yiq = proc_img.RGB_to_YIQ(img1)
img2_yiq = proc_img.RGB_to_YIQ(img2)
img3_yiq = proc_img.RGB_to_YIQ(img1)

# %%
img3_yiq[:,:,0] = img1_yiq[:,:,0] + img2_yiq[:,:,0]
img3_yiq[:,:,1] = img1_yiq[:,:,1] + img2_yiq[:,:,1]
img3_yiq[:,:,2] = img1_yiq[:,:,2] + img2_yiq[:,:,2]

# %%
img3 = proc_img.YIQ_to_RGB(img3_yiq)

# %%
#img3[:,:,1] = img1[:,:,1] * 255
#img3[:,:,2] = img1[:,:,2] * 255

# %%
img3[:,:,0].max()
# Out:
# 255

# %%
cv2.imwrite("pe.png",img3)
# Out:
# True
